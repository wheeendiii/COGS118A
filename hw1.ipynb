# %% [markdown]
# Hongrui Zhu
# A13612523
# Cogs118A hw1

# %% [markdown]
# # Question 1
# Matrix Calculus

# %%
print( "df(x)/dx = λ(1)/dx - λd(a^Tx)/dx = 0 - λa = -λa")
 
print("df(x)/dx = λd(1)/dx - λd(x^TAx)/dx = 0 - 2λAx = -2λAx")
# Out:
# df(x)/dx = λ(1)/dx - λd(a^Tx)/dx = 0 - λa = -λa
# df(x)/dx = λd(1)/dx - λd(x^TAx)/dx = 0 - 2λAx = -2λAx

# %% [markdown]
# # Question 2
# One-hot Encoding

# %%
# let Toyota be 001, BMW be 010, Ford be 011
# Blue be 0001, silver be 0010, red be 0011, black be 0100
s = [[142,52,0,0,1,0,0,0,1],
     [129,35,0,1,0,0,0,1,0],
     [143,29,0,1,0,0,0,1,1],
     [121,78,0,1,1,0,0,0,1],
     [112,83,0,0,1,0,1,0,0]]

# %% [markdown]
# # Question 3
# Basic matrix using numpy

# %%
import numpy as np
A = np.array([[1,2],[3,4],[5,6]])
B = np.array([[1,-1],[-1,1],[1,-1]])

#A+B
print(A+B)

#AoB
print(A*B)

#A^TB
A1 = A.transpose()
print(A1.dot(B))

#AB^T
B1 = B.transpose()
print(A.dot(B1))

#AB is impossible since A is 2x3 B is 2x3 too.
# Out:
# [[2 1]
#  [2 5]
#  [6 5]]
# [[ 1 -2]
#  [-3  4]
#  [ 5 -6]]
# [[ 3 -3]
#  [ 4 -4]]
# [[-1  1 -1]
#  [-1  1 -1]
#  [-1  1 -1]]

# %% [markdown]
# # Question 4
# Basic plots using matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(0)
space = np.linspace(0, 10, num = 50)
sine = np.sin(space)
sine_5 = sine
for i in range(5):
    sine_5 = sine_5 + np.random.normal(scale = 0.1, size = 50)
sine_20 = sine
for i in range(20):
    sine_20 = sine_20 + np.random.normal(scale = 0.1, size = 50)
sine_100 = sine
for i in range(100):
    sine_100 = sine_100 + np.random.normal(scale = 0.1, size = 50)
plt.scatter(space, sine, color = 'b', label = 'sine_curve')
plt.plot(space, sine_5, color = 'r', label = 'noise_5_iters')
plt.plot(space, sine_20, color = 'y', label = 'noise_20_iters')
plt.plot(space, sine_100, color = 'k', label = 'noise_100_iters')
plt.legend(loc = 'upper right')
plt.savefig('./Q4.png')
plt.show()

# %% [markdown]
# # Question 5
# Basic image operations using matplotlib

# %%
import matplotlib.pyplot as plt
img = plt.imread("cat.jpg") # The img here is a NumPy array.
plt.imshow(img)
plt.show()

#print out the shape of the image array
print(img.shape)
# Out:
# (183, 275, 3)

# %% [markdown]
# # Question 6
# Data and visualization

# %%
import matplotlib.pyplot as plt
from sklearn import datasets
from mpl_toolkits.mplot3d import Axes3D

iris = datasets.load_iris()
X = iris.data
Y = iris.target 

plt.scatter(X[:,0],X[:, 1],color = 'b')
plt.show()

fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(X[:,0],X[:,1],X[:,2],color = 'r')
plt.show()

# %% [markdown]
# # Question 7
# Data manipulation

# %%
# show the first 3 features of the first 5 data point
print("question 7.1")
print(X[0:5, 0:3])

# calculate the mean and the variance of the 3rd feature
print("question 7.2")
print("The mean of the 3rd feature is:")
print(X[:,2].mean())
print("The variance of the 3rd feature is:")
print(X[:,2].var())

# linear projection 
print("question 7.3")
import numpy as np
w = np.array([1,2,3,4])
u = np.array(X[:,0:4])
projection = u.dot(w)
print("The shape of the projection is:")
print(projection.shape)
mean = projection.mean()
print("The mean of the projection is:")
print(mean)

# sampled data points
print("question 7.4")
indices = np.random.randint(0,u.shape[0], 4)
print("The random indices are:")
print(indices)
print("The samlped data points are:")
rand = X[indices,:]
print(rand)

# add one more column
print("question 7.5")
add = np.ones((150,5))
add[:,:-1] = X
print("The first row of new array is:")
print(add[0,:])

# add one more row
print("question 7.6")
newRow = X[0,:]
Xplus = np.vstack([X,newRow])
print("The first column is:")
print(Xplus[:,0])
# Out:
# question 7.1
# [[5.1 3.5 1.4]
#  [4.9 3.  1.4]
#  [4.7 3.2 1.3]
#  [4.6 3.1 1.5]
#  [5.  3.6 1.4]]
# question 7.2
# The mean of the 3rd feature is:
# 3.7580000000000005
# The variance of the 3rd feature is:
# 3.0955026666666665
# question 7.3
# The shape of the projection is:
# (150,)
# The mean of the projection is:
# 28.029333333333337
# question 7.4
# The random indices are:
# [102 133  49  69]
# The samlped data points are:
# [[7.1 3.  5.9 2.1]
#  [6.3 2.8 5.1 1.5]
#  [5.  3.3 1.4 0.2]
#  [5.6 2.5 3.9 1.1]]
# question 7.5
# The first row of new array is:
# [5.1 3.5 1.4 0.2 1. ]
# question 7.6
# The first column is:
# [5.1 4.9 4.7 4.6 5.  5.4 4.6 5.  4.4 4.9 5.4 4.8 4.8 4.3 5.8 5.7 5.4 5.1
#  5.7 5.1 5.4 5.1 4.6 5.1 4.8 5.  5.  5.2 5.2 4.7 4.8 5.4 5.2 5.5 4.9 5.
#  5.5 4.9 4.4 5.1 5.  4.5 4.4 5.  5.1 4.8 5.1 4.6 5.3 5.  7.  6.4 6.9 5.5
#  6.5 5.7 6.3 4.9 6.6 5.2 5.  5.9 6.  6.1 5.6 6.7 5.6 5.8 6.2 5.6 5.9 6.1
# ...

# %% [markdown]
# # Question 8
# Line and plan ploting using matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

def f(x):
    with np.errstate(divide='ignore', invalid='ignore'):
        return x-10
    
x = np.linspace(-10,100)
y = f(x)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
xx, yy = np.meshgrid(range(40),range(40))
z = 2*yy - xx - 8
ax = fig.gca(projection = '3d')
ax.plot_surface(xx,yy,z, shade = False)
plt.show()
